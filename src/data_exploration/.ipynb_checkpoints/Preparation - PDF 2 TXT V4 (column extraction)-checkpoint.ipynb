# %% [markdown]
# Action performed:
# - PDFminer for pdf to txt conversion, for all input pdfs
# - From txt, description using nltk
# - summarization using nltk

# %%
# general imports
from pathlib import Path
import os

# processing imports
import pandas as pd
import summa

# %%
# utils elements to move to utils after development

def getListOfFiles(dirName):
    '''
        For the given path, get the List of all files in the directory tree 
    '''
    paths = []
    for path, subdirs, files in os.walk(dirName):
        for name in files:
            paths.append((Path(path+name)))            
    return paths

from pdfminer.pdfdocument import PDFDocument, PDFNoOutlines
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTPage, LTChar, LTAnno, LAParams, LTTextBox, LTTextLine

class PDFPageDetailedAggregator(PDFPageAggregator):
    def __init__(self, rsrcmgr, pageno=1, laparams=None):
        PDFPageAggregator.__init__(self, rsrcmgr, pageno=pageno, laparams=laparams)
        self.rows = []
        self.page_number = 0
    def receive_layout(self, ltpage):        
        def render(item, page_number):
            if isinstance(item, LTPage) or isinstance(item, LTTextBox):
                for child in item:
                    render(child, page_number)
            elif isinstance(item, LTTextLine):
                child_str = ''
                for child in item:
                    if isinstance(child, (LTChar, LTAnno)):
                        child_str += child.get_text()
                child_str = ' '.join(child_str.split()).strip()
                if child_str:
                    row = (page_number, item.bbox[0], item.bbox[1], item.bbox[2], item.bbox[3], child_str) # bbox == (x1, y1, x2, y2)
                    self.rows.append(row)
                for child in item:
                    render(child, page_number)
            return
        render(ltpage, self.page_number)
        self.page_number += 1
        self.rows = sorted(self.rows, key = lambda x: (x[0], -x[2]))
        self.result = ltpage

from collections import OrderedDict
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams

# TODO: deal with words cut in half "pro- pagation of..."
def convert(input_file, rse_ranges):
    """
    :param input_file: PDF filename
    :param pages_range: (nb_first_page_rse:int, nb_last_page_rse:int), starting at 1
    """
    fp = open(input_file, 'rb')
    parser = PDFParser(fp)
    doc = PDFDocument(parser)
    # doc.initialize("passwrd") # leave empty for no password

    rsrcmgr = PDFResourceManager()
    laparams = LAParams()
    device = PDFPageDetailedAggregator(rsrcmgr, laparams=laparams)
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    
    pages_selection = range(rse_ranges[0]-1,(rse_ranges[1]-1)+1)
    for nb_page_parsed, page in enumerate(PDFPage.create_pages(doc)):
        if nb_page_parsed in pages_selection:
            interpreter.process_page(page)
            # receive the LTPage object for this page
            device.get_result()

    # GROUPING
    grouped_text = OrderedDict() # keep order is of identification in the document.
    for (page_nb, x_min, y_min, x_max, y_max, text) in device.rows:
        page_nb = (pages_range[0]) + page_nb # elsewise device starts again at 0
        if page_nb not in grouped_text.keys():
            grouped_text[page_nb] = {}
        x_min = round(x_min)//10 # manipulate the level of aggregation,(unit?) --> x_min might be slighly adapted
        try:
            grouped_text[page_nb][x_min]+= " " + text # TODO: check if anomaly in paragraphe here
        except:
            grouped_text[page_nb][x_min] = text
    
    return grouped_text
    
###     KEEP for FUTURE  AGGREGATION
#     # FULL TEXT BY PAGE
#     text_by_page = OrderedDict()
#     for key, values in grouped_text.items():
#         if values:
#             text_by_page[key] = ""
#             for _, text in values.items():
#                 text_by_page[key] += text + " "
#     # FULL TEXT
#     pdf_full_txt = ""
#     for key, text in text_by_page.items():
#         pdf_full_txt += text + " "
        
#     return (pdf_full_txt, text_by_page)

# %%
entreprises_filename = "../../data/input/Entreprises/entreprises.csv"
df_entreprises = pd.read_csv(entreprises_filename, sep=";")
pd.read_csv(entreprises_filename, sep=";").set_index("project_denomination").T.to_dict()
# Out:
# {'vinci': {'SIREN': 552037806,
#   'denomination': 'VINCI',
#   'rse_ranges': '(38,48)|(207,266)'},
#  'eiffage': {'SIREN': 709802094,
#   'denomination': 'Eiffage',
#   'rse_ranges': '(125,202)'},
#  'bouygues': {'SIREN': 397480930,
#   'denomination': 'Bouygues',
#   'rse_ranges': '(98,124)'},
#  'saintgobain': {'SIREN': 542039532,
#   'denomination': 'Saint-Gobain',
#   'rse_ranges': '(76,79)|(101,104)|(329,332)'}}

# %%
# filepaths
entreprises_filename = "../../data/input/Entreprises/entreprises.csv"
input_path = "../../data/input/DPEFs/Construction/"
output_filename= "../../data/processed/DPEFs/dpef_paragraphs.csv"

# Entreprises : data
dict_entreprises = pd.read_csv(entreprises_filename, sep=";").set_index("project_denomination").T.to_dict()
# Looks like 'vinci': {'SIREN': 552037806, 'denomination': 'VINCI'},

# DPEF
all_input_files = getListOfFiles(input_path)
all_input_files = [p for p in all_input_files if p.name.lower().endswith(".pdf")]

# output has shape...
df_parsed_data = pd.DataFrame(columns = ["SIREN", 
                                         "project_denomination", 
                                         "pdf_name", 
                                         "page_nb_in_pdf",
                                         "paragraph_id", # x_min for now
                                         "paragraph"])
for i, input_file in enumerate(all_input_files):
    if input_file.name.endswith("pdf"):
        project_denomination = input_file.name.split("\\")[-1].split("_")[0] # first word of pdf name
        print("Processing {}/{} {} [{}]".format(i,len(all_input_files),project_denomination, input_file.name))
        for rse_ranges in dict_entreprises[project_denomination]["rse_ranges"].split("|"):
            rse_ranges = eval(rse_ranges) # tuple format str to actual tuple
            print("Pages: {} to {}".format(rse_ranges[0], rse_ranges[1]))
            grouped_text = convert(input_file, rse_ranges)
            for page_nb, page_content in grouped_text.items():
                for paragraph_id, paragraph in page_content.items():
                    df_update = {"SIREN": dict_entreprises[project_denomination]["SIREN"],
                                 "denomination": dict_entreprises[project_denomination]["denomination"],
                                 "project_denomination": project_denomination,
                                 "pdf_name": input_file.name.split("\\")[-1],
                                 "page_nb_in_pdf":page_nb,
                                 "paragraph_id":paragraph_id,
                                 "paragraph":paragraph}
                    df_parsed_data = df_parsed_data.append(df_update, ignore_index=True)
df_parsed_data.to_csv(output_filename,sep=";", index=False)
# Out:
# Processing 0/4 bouygues [bouygues_2018_ddr.pdf]
# Pages: 98 to 124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0b8568a1772f> in <module>
#      26             rse_ranges = eval(rse_ranges) # tuple format str to actual tuple
#      27             print("Pages: {} to {}".format(rse_ranges[0], rse_ranges[1]))
# ---> 28             grouped_text = convert(input_file, rse_ranges)
#      29             for page_nb, page_content in grouped_text.items():
#      30                 for paragraph_id, paragraph in page_content.items():
#
# <ipython-input-2-d34c0d3320c2> in convert(input_file, pages_range)
#      70     for nb_page_parsed, page in enumerate(PDFPage.create_pages(doc)):
#      71         if nb_page_parsed in pages_selection:
# ---> 72             interpreter.process_page(page)
#      73             # receive the LTPage object for this page
#      74             device.get_result()
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\pdfinterp.py in process_page(self, page)
#     894         self.device.begin_page(page, ctm)
#     895         self.render_contents(page.resources, page.contents, ctm=ctm)
# --> 896         self.device.end_page(page)
#     897         return
#     898
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\converter.py in end_page(self, page)
#      47         assert isinstance(self.cur_item, LTPage), str(type(self.cur_item))
#      48         if self.laparams is not None:
# ---> 49             self.cur_item.analyze(self.laparams)
#      50         self.pageno += 1
#      51         self.receive_layout(self.cur_item)
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\layout.py in analyze(self, laparams)
#     728         if -1 <= laparams.boxes_flow and laparams.boxes_flow <= +1 \
#     729                 and textboxes:
# --> 730             self.groups = self.group_textboxes(laparams, textboxes)
#     731             assigner = IndexAssigner()
#     732             for group in self.groups:
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\layout.py in group_textboxes(self, laparams, boxes)
#     702                 else:
#     703                     group = LTTextGroupLRTB([obj1, obj2])
# --> 704                 plane.remove(obj1)
#     705                 plane.remove(obj2)
#     706                 done.update([id1, id2])
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\utils.py in remove(self, obj)
#     354     def remove(self, obj):
#     355         """displace an object."""
# --> 356         for k in self._getrange((obj.x0, obj.y0, obj.x1, obj.y1)):
#     357             try:
#     358                 self._grid[k].remove(obj)
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\utils.py in _getrange(self, bbox)
#     332         x1 = min(self.x1, x1)
#     333         y1 = min(self.y1, y1)
# --> 334         for grid_y in drange(y0, y1, self.gridsize):
#     335             for grid_x in drange(x0, x1, self.gridsize):
#     336                 yield (grid_x, grid_y)
#
# ~\Miniconda3\envs\base_ml_env\lib\site-packages\pdfminer\utils.py in drange(v0, v1, d)
#     155 def drange(v0, v1, d):
#     156     """Returns a discrete range."""
# --> 157     return range(int(v0) // d, int(v1 + d) // d)
#     158
#     159
#
# KeyboardInterrupt:

# %%
df_parsed_data.head()

# %%
# from summa.summarizer import summarize
summa.summarizer.summarize("Des bâtiments performants énergétiquement, offrant une haute qualité d’usage à leurs habitants Eiffage Énergie Systèmes a présenté début mars 2018 son dispositif de supervision numérique énergétique des bâtiments publics, une première en Europe. Eiffage Énergie Systèmes réalise ainsi le système de supervision de la Ville de Paris. Les équipes de la branche sont chargées de la rénovation des installations techniques – instrumentation, compteurs, tableaux électriques, automates –, d’une partie des centres thermiques et de la mise en place d’un système de supervision pour l’ensemble du parc qui s’interfacera avec les outils de gestion interne existants. Afin d’affiner les données collectées, les équipes installent des cap- teurs intelligents sur les centres thermiques les plus importants et sont chargées du développement et de l’installation du logiciel pour organiser et mettre à disposition les données collectées. Par la collecte et l’exploitation de données via un réseau spécifique Internet des Objets (IoT), accompagnées d’une maintenance préventive et curative, ce dispositif favorisera une véritable démarche de management de l’énergie, et créera de nouveaux services et applications à destination des usagers. Par ailleurs, Eiffage Énergie Systèmes a signé en 2010 un contrat de performance énergétique (CPE) avec la région Centre, sur l’exploi- tation des installations énergétiques de 19 lycées durant quinze ans. L’entreprise s’est engagée à réaliser des économies d’énergie de l’ordre de 35 % et une réduction des gaz à effet de serre de 49 % d’ici à 2025. Leader français de la cogénération dans le maraîchage Eiffage Énergie Systèmes est le leader français de la cogénération dans le maraîchage, avec 116 installations en France pour 500 MWh électriques et 500 MWh thermiques installés. Ce procédé récupère le CO2 afin de favoriser la photosynthèse et produire de l’électricité, revendue par les maraîchers. La conception, l’installation et l’exploitation-maintenance de ces centrales de cogénération sont assurées par la branche et certifiées ISO 50001. Nouvelles mobilités et covoiturage Eiffage Énergie Systèmes est un moteur du développement des nouvelles mobilités, comme l’atteste le test dès janvier 2019 de la première navette autonome capable de circuler sur route ouverte en zone d’activités, baptisée Mia. Les équipes participent égale- ment au développement des réseaux de bornes de recharge élec- trique en milieu urbain comme sur autoroute. Présentée le 27 novembre par Eiffage Énergie Systèmes et ses par- tenaires au salon Pollutec, le Salon des solutions environnementales pour l’industrie, la ville et les territoires, la navette autonome Mia a;Eiffage", 
                           words=100, 
                           split=True, 
                           language="french")
# Out:
# ['Leader français de la cogénération dans le maraîchage Eiffage Énergie Systèmes est le leader français de la cogénération dans le maraîchage, avec 116 installations en France pour 500 MWh électriques et 500 MWh thermiques installés.',
#  'Nouvelles mobilités et covoiturage Eiffage Énergie Systèmes est un moteur du développement des nouvelles mobilités, comme l’atteste le test dès janvier 2019 de la première navette autonome capable de circuler sur route ouverte en zone d’activités, baptisée Mia. Les équipes participent égale- ment au développement des réseaux de bornes de recharge élec- trique en milieu urbain comme sur autoroute.',
#  'Présentée le 27 novembre par Eiffage Énergie Systèmes et ses par- tenaires au salon Pollutec, le Salon des solutions environnementales pour l’industrie, la ville et les territoires, la navette autonome Mia a;Eiffage']

# %%
fp = open(input_file, 'rb')
parser = PDFParser(fp)
doc = PDFDocument(parser)
# doc.initialize("passwrd") # leave empty for no password

rsrcmgr = PDFResourceManager()
laparams = LAParams()
device = PDFPageDetailedAggregator(rsrcmgr, laparams=laparams)
interpreter = PDFPageInterpreter(rsrcmgr, device)

pages_selection = range(rse_ranges[0]-1,(rse_ranges[1]-1)+1)
for nb_page_parsed, page in enumerate(PDFPage.create_pages(doc)):
    if nb_page_parsed in pages_selection:
        interpreter.process_page(page)
        # receive the LTPage object for this page
        device.get_result()

# %%
device.rows
# etape un : un etxt = deux points
# - par page checker les intersection
# - grouper si intersection
# - merge le texte dans l'ordre.
# Out:
# [(0,
#   99.2126,
#   783.1738,
#   435.2076,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (0,
#   74.6853,
#   769.213125,
#   237.02960000000002,
#   798.502125,
#   '3 Informations environnementales'),
#  (0, 99.2126, 721.248, 127.15979999999999, 737.248, '3.3'),
#  (0,
#   138.9102,
#   721.248,
#   428.91979999999995,
#   737.248,
#   'INFORMATIONS ENVIRONNEMENTALES'),
#  (0,
#   99.2126,
#   691.7935,
#   595.2752400000022,
#   699.7935,
#   'Des informations complémentaires sont disponibles sur bouygues.com, ainsi que dans les documentations RSE des métiers, disponibles sur leurs sites internet.'),
#  (0,
#   99.2126,
#   656.9759,
#   459.7260999999999,
#   671.4759,
#   '3.3.1 Politique générale en matière d’environnement'),
#  (0,
#   354.32939999999996,
#   628.0168,
#   597.3918399999999,
#   636.0568000000001,
#   'En phase de conception, tous les métiers du Groupe prennent en compte les'),
#  (0,
#   99.2126,
#   624.0994000000001,
#   278.6174,
#   636.0994000000001,
#   '3.3.1.1 Politique environnementale'),
#  (0,
#   354.32939999999996,
#   617.0568000000001,
#   597.4085600000005,
#   625.0568000000001,
#   'questions environnementales dans une partie de leurs offres de produits et de'),
#  (0,
#   354.32939999999996,
#   606.0568000000001,
#   595.2608,
#   614.0568000000001,
#   'services. Cela s’illustre notamment pour les métiers de la construction par :'),
#  (0,
#   99.2126,
#   602.8568,
#   342.29556000000014,
#   610.8568,
#   'La question environnementale est identiﬁ ée comme stratégique pour le'),
#  (0,
#   99.2126,
#   591.8568,
#   342.2940399999995,
#   599.8568,
#   'groupe Bouygues qui a vocation à ﬁ gurer parmi les apporteurs de solutions'),
#  (0,
#   354.3307,
#   591.3207000000001,
#   597.4036000000001,
#   601.3207000000001,
#   '• les labels et certiﬁ cations environnementales des produits (BREEAM®, LEED®,'),
#  (0,
#   361.41600000000005,
#   581.2207000000001,
#   588.3940000000001,
#   591.343457,
#   'HQE™, BBC-efﬁ nergie®, BiodiverCity®, Minergie a, E+C- b, BBCA c, etc.) ;'),
#  (0,
#   99.2126,
#   580.8568,
#   342.2849199999999,
#   588.8568,
#   'face aux déﬁ s planétaires que représentent les dérèglements climatiques'),
#  (0,
#   99.2126,
#   569.8568,
#   342.28491999999983,
#   577.8568,
#   'et la raréfaction des ressources. La construction durable et l’aménagement'),
#  (0,
#   354.3306,
#   566.486,
#   597.4047999999998,
#   576.486,
#   '• des démarches d’économie circulaire (participation à la création et à la'),
#  (0,
#   99.2126,
#   558.8568,
#   342.29404000000005,
#   566.8568,
#   'urbain font partie de ces solutions. Aﬁ n d’être cohérent avec cette démarche,'),
#  (0,
#   361.4172,
#   556.386,
#   597.3858000000001,
#   564.386,
#   'gouvernance du label BBCA (cf. paragraphe 3.3.4.4) qui intègre des critères'),
#  (0,
#   99.2126,
#   547.8568,
#   342.2765599999998,
#   555.8568,
#   'le Groupe mène des actions pilotées à l’aide d’indicateurs dans l’objectif de'),
#  (0,
#   361.4172,
#   545.386,
#   597.3835200000002,
#   553.386,
#   'd’économie circulaire tout au long du cycle de vie du bâtiment (nouvelles'),
#  (0,
#   99.2126,
#   536.8568,
#   299.7766,
#   544.8568,
#   'maîtriser et réduire l’impact environnemental de ses activités.'),
#  (0,
#   361.4172,
#   534.386,
#   511.8744,
#   542.386,
#   'méthodes de déconstruction sélective, etc.)) ;'),
#  (0,
#   99.2126,
#   523.0248,
#   342.2872000000003,
#   531.0248,
#   'Les politiques environnementales des métiers du Groupe couvrent différentes'),
#  (0,
#   354.3306,
#   519.6513,
#   595.2798399999999,
#   529.6513,
#   '• des démarches d’analyse de cycle de vie (ACV) et la proposition d’éco-'),
#  (0,
#   99.2126,
#   512.0248,
#   180.70739999999998,
#   520.0248,
#   'phases de leurs activités.'),
#  (0, 361.4172, 509.55140000000006, 392.5772, 517.5514000000001, 'variantes.'),
#  (0,
#   354.334,
#   495.71940000000006,
#   597.4108799999999,
#   503.71940000000006,
#   'La construction durable et la recherche de solutions pour l’environnement'),
#  (0,
#   354.334,
#   484.71940000000006,
#   597.3956799999999,
#   492.71940000000006,
#   'sont des thématiques prioritaires d’innovation pour Bouygues Construction,'),
#  (0,
#   354.334,
#   473.71940000000006,
#   453.6432000000001,
#   481.71940000000006,
#   'Bouygues Immobilier et Colas.'),
#  (0,
#   99.2126,
#   113.367,
#   597.1563800000006,
#   120.067,
#   '(a) Minergie® et Minergie-eco® sont des labels de performance européens d’origine suisse, déployés principalement par Losinger Marazzi, ﬁ liale helvétique de'),
#  (0,
#   109.1324,
#   105.36720000000001,
#   182.58450000000002,
#   112.0672,
#   'Bouygues Construction.'),
#  (0,
#   99.2097,
#   95.94700000000002,
#   597.1215399999999,
#   102.647,
#   '(b) Le label E+C- (Énergie + Carbone −/Bâtiment à énergie positive et Réduction Carbone) est un label expérimental réglementaire préﬁ gurant la future réglementation'),
#  (0,
#   109.13239999999996,
#   87.94720000000002,
#   597.1570500000005,
#   94.64720000000001,
#   'énergétique. La méthodologie développée par l’État a fait l’objet d’une large concertation des parties prenantes qui a abouti à la publication d’une méthode et'),
#  (0,
#   109.13239999999996,
#   79.94740000000003,
#   425.21830000000006,
#   86.64740000000002,
#   'd’un référentiel technique dont les éléments sont intégrés dans le label BBCA et le label Efﬁ nergie 2017.'),
#  (0,
#   99.2097,
#   70.52720000000004,
#   373.8628000000001,
#   77.22720000000002,
#   '(c) Le label BBCA atteste de l’exemplarité d’un bâtiment en matière d’empreinte carbone.'),
#  (0,
#   85.0394,
#   49.879599999999996,
#   264.15990000000016,
#   56.379599999999996,
#   '96 • BOUYGUES • DOCUMENT DE RÉFÉRENCE 2018'),
#  (1,
#   245.1104,
#   783.1738,
#   581.1054000000001,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (1, 443.1522, 770.3225, 580.9692, 779.3225, 'Informations environnementales'),
#  (1,
#   70.8661,
#   727.1279000000001,
#   243.4551,
#   737.1279000000001,
#   'Indicateur de Bouygues Construction'),
#  (1, 189.7061, 707.1458, 229.0101, 715.1458, 'Périmètre'),
#  (1, 165.4741, 697.5458, 229.01010000000002, 705.5458, '(organisationnel'),
#  (1, 70.8661, 687.9458, 109.3021, 695.9458, 'Indicateur'),
#  (1,
#   181.2741,
#   687.9458,
#   280.62610000000006,
#   695.9458,
#   'ou régional) Couverture'),
#  (1, 331.49809999999997, 687.9458, 405.7941, 695.9458, '2017 Commentaire'),
#  (1, 296.9781, 687.9458, 314.64209999999997, 695.9458, '2018'),
#  (1, 70.8661, 674.8919, 139.76350000000002, 682.6919, 'Part des dépenses'),
#  (1,
#   202.15570000000002,
#   674.8529000000001,
#   226.79590000000002,
#   682.6529,
#   'Monde'),
#  (1, 263.4988, 674.8529000000001, 282.8233, 682.6529, '98 %'),
#  (1,
#   331.8112,
#   674.8373000000001,
#   569.1191799999998,
#   682.6373000000001,
#   '39 % Une part importante des dépenses de R&D concerne la RSE'),
#  (1, 297.4717, 674.8373000000001, 314.63638, 682.6373000000001, '28 %'),
#  (1, 70.8661, 666.8891, 142.8367, 674.6891, 'de R&D consacrées'),
#  (1,
#   247.4035,
#   666.8501000000001,
#   282.81550000000004,
#   674.6501000000001,
#   'du chiffre'),
#  (1,
#   354.3337,
#   666.8345000000002,
#   491.62149999999997,
#   674.6345000000001,
#   'et notamment la construction durable.'),
#  (1, 70.8661, 658.8863, 99.2932, 666.6863000000001, 'à la RSE'),
#  (1,
#   248.8231,
#   658.8473000000001,
#   282.81550000000004,
#   666.6473000000001,
#   'd’affaires'),
#  (1,
#   354.3337,
#   658.8317000000002,
#   562.8978999999999,
#   666.6317000000001,
#   'En 2018, la méthodologie de répartition des dépenses sur'),
#  (1,
#   234.2761,
#   650.8445000000002,
#   282.81550000000004,
#   658.6445000000001,
#   'consolidé de'),
#  (1,
#   354.3337,
#   650.8289000000002,
#   557.4223,
#   658.6289000000002,
#   'les trois grandes thématiques d’engagement du Groupe'),
#  (1,
#   245.52370000000002,
#   642.8417000000002,
#   282.81550000000004,
#   650.6417000000001,
#   'Bouygues'),
#  (1,
#   354.3337,
#   642.8261000000002,
#   552.4693,
#   650.6261000000002,
#   '(la RSE, ses clients et la productivité) a été afﬁ née pour'),
#  (1,
#   234.51790000000003,
#   634.8389000000002,
#   280.6315,
#   642.6389000000001,
#   'Construction'),
#  (1,
#   354.3337,
#   634.8233000000002,
#   549.3102999999999,
#   642.6233000000002,
#   'harmoniser la façon dont les contributions sur les trois'),
#  (1,
#   354.3337,
#   626.8205000000003,
#   469.1107,
#   634.6205000000002,
#   'thématiques sont incrémentées.'),
#  (1,
#   354.3337,
#   618.8177000000003,
#   558.7522,
#   626.6177000000002,
#   'Ainsi, la RSE constitue 28 % des dépenses de R&D et elle'),
#  (1,
#   354.3337,
#   610.8149000000003,
#   547.8282999999999,
#   618.6149000000003,
#   'est pratiquement équivalente aux thématiques clients'),
#  (1,
#   354.3337,
#   602.8121000000003,
#   457.6915,
#   610.6121000000003,
#   '(39 %) et productivité (33 %).'),
#  (1,
#   354.3337,
#   594.8093000000003,
#   541.6506999999999,
#   602.6093000000003,
#   'Le reporting de cet indicateur est fait sur une année'),
#  (1, 354.3337, 586.8065000000004, 393.4273, 594.6065000000003, 'calendaire.'),
#  (1,
#   70.86610000000002,
#   573.7337000000002,
#   139.21750000000003,
#   581.5337000000003,
#   'Part de la prise de'),
#  (1,
#   202.15570000000002,
#   573.6791000000005,
#   226.78030000000004,
#   581.4791000000005,
#   'Monde'),
#  (1,
#   263.5729,
#   573.6713000000005,
#   282.81550000000004,
#   581.4713000000005,
#   '48 %'),
#  (1, 297.5887, 573.6557000000006, 314.6473, 581.4557000000005, '48 %'),
#  (1,
#   331.7137,
#   573.6557000000006,
#   549.8250999999999,
#   581.4557000000005,
#   '69 % Lorsque Bouygues Construction intervient en tant que'),
#  (1,
#   70.86610000000002,
#   565.7309000000002,
#   150.06730000000002,
#   573.5309000000003,
#   'commandes annuelle'),
#  (1, 195.9781, 565.6763000000005, 228.9565, 573.4763000000005, 'Activités'),
#  (1,
#   247.4035,
#   565.6685000000006,
#   282.81550000000004,
#   573.4685000000005,
#   'du chiffre'),
#  (1,
#   354.3337,
#   565.6529000000006,
#   561.1974999999999,
#   573.4529000000006,
#   'concepteur/constructeur, le Groupe s’attache à proposer'),
#  (1,
#   70.86610000000002,
#   557.7281000000003,
#   143.92090000000002,
#   565.5281000000003,
#   'des bâtiments avec'),
#  (1,
#   194.85490000000001,
#   557.6735000000006,
#   226.7725,
#   565.4735000000005,
#   'Bâtiment'),
#  (1,
#   248.8231,
#   557.6657000000006,
#   282.81550000000004,
#   565.4657000000005,
#   'd’affaires'),
#  (1,
#   354.3337,
#   557.6501000000006,
#   543.9127,
#   565.4501000000006,
#   'des engagements de certiﬁ cation et/ou labellisation'),
#  (1,
#   70.86610000000002,
#   549.7253000000003,
#   142.08790000000002,
#   557.5253000000004,
#   'un engagement de'),
#  (1,
#   234.2761,
#   549.6629000000006,
#   282.81550000000004,
#   557.4629000000006,
#   'consolidé de'),
#  (1,
#   354.3337,
#   549.6473000000007,
#   564.4735,
#   557.4473000000006,
#   'supérieurs à la réglementation en vigueur, lorsque cela est'),
#  (1,
#   70.86610000000002,
#   541.7225000000003,
#   140.15350000000004,
#   549.5225000000004,
#   'certiﬁ cation ou de'),
#  (1,
#   245.52370000000002,
#   541.6601000000006,
#   282.81550000000004,
#   549.4601000000006,
#   'Bouygues'),
#  (1, 354.3337, 541.6445000000007, 386.3449, 549.4445000000006, 'possible.'),
#  (1,
#   70.86610000000002,
#   533.7197000000003,
#   141.8305,
#   541.5197000000004,
#   'labellisation quand'),
#  (1,
#   234.51790000000003,
#   533.6573000000006,
#   280.6315,
#   541.4573000000006,
#   'Construction'),
#  (1,
#   354.3337,
#   533.6417000000007,
#   536.9863,
#   541.4417000000007,
#   'Le recul de cet indicateur en 2018 tient à une prise'),
#  (1,
#   70.86610000000002,
#   525.7169000000004,
#   158.18710000000002,
#   533.5169000000004,
#   'Bouygues Construction'),
#  (1,
#   354.3337,
#   525.6389000000007,
#   538.1406999999999,
#   533.4389000000007,
#   'de commande signiﬁ cative par Bouygues Bâtiment'),
#  (1,
#   70.86610000000002,
#   517.7141000000004,
#   128.91370000000003,
#   525.5141000000004,
#   'est prescripteur'),
#  (1,
#   354.3337,
#   517.6361000000007,
#   563.0858800000001,
#   525.4361000000007,
#   'International ne comprenant pas d’engagement à ce titre.'),
#  (1,
#   354.3337,
#   509.6333000000007,
#   559.1929,
#   517.4333000000007,
#   'La moitié des prises de commandes dispose malgré cela'),
#  (1,
#   354.3337,
#   501.6305000000007,
#   531.9475,
#   509.43050000000073,
#   'd’un engagement de certiﬁ cation ou labellisation.'),
#  (1, 597.9988, 489.07212499999997, 616.5094479999999, 518.361125, '3'),
#  (1,
#   70.8661,
#   481.5942,
#   569.3398200000021,
#   491.5942,
#   '• Sur les opérations du Groupe (principalement sur les chantiers et les sites ﬁ xes tels que les ateliers et les sites de production), la maîtrise des impacts'),
#  (1,
#   77.9527,
#   471.49420000000003,
#   569.0571000000001,
#   479.4943,
#   'environnementaux repose essentiellement sur l’utilisation de systèmes de management environnemental (Iso 14001) et de certiﬁ cations (HQE™, LEED®,'),
#  (1,
#   77.95270000000005,
#   460.49420000000003,
#   128.0736,
#   468.49420000000003,
#   'BREEAM®, etc.).'),
#  (1,
#   70.8661,
#   445.7596,
#   569.0570999999994,
#   455.7596,
#   '• Au-delà de ces outils, les activités de construction du groupe Bouygues ont développé leurs propres démarches d’évaluation de la performance'),
#  (1,
#   77.9527,
#   435.6596,
#   569.0647000000022,
#   443.6596,
#   'environnementale. Celles-ci tiennent compte des spéciﬁ cités de leur métier : Ecosite et Top Site (cf. paragraphe 3.3.1.2) pour Bouygues Construction,'),
#  (1,
#   77.9527,
#   424.6596,
#   569.0609000000023,
#   432.6596,
#   'l’auto-évaluation environnementale par check-lists pour Colas et la charte des chantiers à faibles nuisances pour Bouygues Immobilier. Cette charte des'),
#  (1,
#   77.9527,
#   413.6596,
#   569.07002,
#   421.6596,
#   'chantiers à faibles nuisances s’applique sur l’ensemble des programmes d’immobilier d’entreprise (10,25 % du chiffre d’affaires de Bouygues Immobilier) et'),
#  (1,
#   77.9527,
#   402.6596,
#   566.9128000000005,
#   410.6596,
#   'sur les opérations de logements certiﬁ ées NF Habitat HQE™ représentant 25 % de ses projets Logement (périmètre Logement : 89,7 % du chiffre d’affaires).'),
#  (1,
#   70.8661,
#   387.9249,
#   569.3231000000022,
#   397.9249,
#   '• Dans le cadre de ses processus internes, le Groupe mène une politique de certiﬁ cation environnementale pour la construction et l’exploitation de ses'),
#  (1,
#   77.9527,
#   377.8249,
#   569.0548200000004,
#   385.8249,
#   'propres bâtiments : les sièges sociaux de Bouygues SA, Bouygues Construction et Bouygues Immobilier, les sites du Technopôle, de Printania (l’un des'),
#  (1,
#   77.9527,
#   366.8249,
#   569.0533,
#   374.8249,
#   'centres de relation client) et le data centre de Bouygues Telecom, ainsi que le nouveau siège de Colas, Prism’, sont certiﬁ és (cf. rubrique 1.1.5, Principaux'),
#  (1,
#   77.9527,
#   355.8249,
#   283.09950000000003,
#   363.8249,
#   'sites du groupe Bouygues au chapitre 1 du présent document).'),
#  (1,
#   82.0145928,
#   306.5777,
#   344.6425000000001,
#   318.5777,
#   'Prism’, le nouveau siège de Colas à énergie positive'),
#  (1,
#   82.4547,
#   286.71110000000004,
#   557.6636999999997,
#   294.71110000000004,
#   'Prism’, nouveau siège social parisien de Colas, a été inauguré le 9 juillet 2018 après deux ans et demi de travaux. Il accueille aujourd’hui les'),
#  (1,
#   82.4547,
#   277.1111,
#   557.4645799999994,
#   285.1111,
#   '350 collaborateurs de Colas précédemment installés à Boulogne-Billancourt. Ce projet est le résultat de la synergie des métiers du Groupe : ce'),
#  (1,
#   82.4547,
#   267.5111,
#   557.4623000000023,
#   275.5111,
#   'bâtiment a été érigé par Bouygues Bâtiment Ile-de-France Construction Privée, entité de Bouygues Construction, pour le compte du promoteur'),
#  (1, 82.4547, 257.9111, 154.37805999999995, 265.9111, 'Bouygues Immobilier.'),
#  (1,
#   82.4547,
#   245.4765,
#   557.46938,
#   253.47909999999996,
#   'Premier Green Ofﬁ ce® construit en entreprise générale, Prism’ est exemplaire en matière de performance énergétique. Trois certiﬁ cations'),
#  (1,
#   82.45189999999997,
#   235.8764,
#   557.4704,
#   243.8765,
#   'environnementales lui ont été délivrées : Bepos-Efﬁ nergie 2013, HQE™ Exceptionnel millésime 2015 et BREEAM® International 2013, Excellent.'),
#  (1,
#   82.45519999999999,
#   226.2764,
#   557.4705199999995,
#   234.2764,
#   'Il dispose de 540 m2 de panneaux photovoltaïques en toiture et d’une centrale de cogénération à l’huile végétale de colza lui permettant de'),
#  (1,
#   82.4538,
#   216.6764,
#   278.7313999999999,
#   224.6764,
#   'produire plus d’énergie renouvelable qu’il n’en consomme.'),
#  (1,
#   70.6161,
#   177.0967,
#   313.67702000000037,
#   185.0967,
#   'Compte tenu de la nature des produits et services du Groupe, les politiques'),
#  (1,
#   325.7329,
#   177.0967,
#   568.7892600000002,
#   185.0967,
#   'Les certiﬁ cations environnementales liées à l’exploitation des bâtiments'),
#  (1,
#   70.6161,
#   166.0967,
#   313.69145999999967,
#   174.0967,
#   'et démarches de performance environnementale en phase d’exploitation des'),
#  (1,
#   325.7329,
#   166.0966,
#   569.0135,
#   174.0967,
#   '(HQE™ Exploitation, LEED®, BREEAM® in use), et dont les métiers sont les'),
#  (1,
#   70.6161,
#   155.0967,
#   313.6944999999998,
#   163.0967,
#   'ouvrages ont une importance déterminante. Ainsi, Bouygues Construction'),
#  (1,
#   325.73750000000007,
#   155.0966,
#   568.8235000000005,
#   163.0966,
#   'prescripteurs, comportent des exigences de gestion de l’énergie et des'),
#  (1,
#   70.6161,
#   144.0967,
#   313.6853800000001,
#   152.0967,
#   'et Bouygues Immobilier accompagnent leurs clients dans le pilotage et la'),
#  (1,
#   325.73750000000007,
#   144.0966,
#   495.1073,
#   152.0966,
#   'ressources dans le volet Exploitation − Maintenance.'),
#  (1,
#   70.6161,
#   133.0967,
#   313.6868999999998,
#   141.0967,
#   'maîtrise de leurs consommations ﬁ nales. Ils proposent, par exemple, des'),
#  (1,
#   70.6161,
#   122.0967,
#   313.6952600000003,
#   130.0967,
#   'offres intégrant des engagements de performance par des contrats de'),
#  (1,
#   70.6161,
#   111.0967,
#   313.69297999999986,
#   119.0967,
#   'performance énergétique (CPE) dans l’immobilier tertiaire et le logement'),
#  (1,
#   70.6161,
#   100.0967,
#   146.92009999999996,
#   108.0967,
#   '(cf. paragraphe 3.3.3.2).'),
#  (1,
#   402.8696,
#   49.8277,
#   581.6716,
#   56.5552,
#   'BOUYGUES • DOCUMENT DE RÉFÉRENCE 2018 • 97'),
#  (2,
#   99.2126,
#   783.1738,
#   435.2076,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (2,
#   74.6853,
#   769.213125,
#   237.02960000000002,
#   798.502125,
#   '3 Informations environnementales'),
#  (2,
#   354.32939999999996,
#   729.1456000000001,
#   597.3773999999999,
#   737.1456000000001,
#   's’engagent à mener pour améliorer la performance environnementale du'),
#  (2, 99.2126, 725.188, 258.6206, 737.188, '3.3.1.2 Prévention des risques'),
#  (2,
#   354.32939999999996,
#   718.1456000000001,
#   597.4260400000001,
#   726.1456000000001,
#   'Groupe. Les systèmes de management (Iso 14001, Iso 50001 et Iso 9001),'),
#  (2, 138.8966, 712.192, 232.4126, 724.192, 'environnementaux'),
#  (2,
#   354.32939999999996,
#   707.1439,
#   597.4037000000001,
#   715.1456000000001,
#   'ainsi que les certiﬁ cations environnementales (HQE™, LEED®, BREEAM®)'),
#  (2,
#   354.3329,
#   696.1439,
#   597.4113,
#   704.1439,
#   'déployés sur les opérations du Groupe, permettent de cadrer la démarche'),
#  (2, 354.3329, 685.1439, 467.1701, 693.1439, 'de management environnemental.'),
#  (2, 99.2126, 678.2068, 189.27260000000004, 688.2068, 'Analyse des risques'),
#  (2,
#   354.3329,
#   671.3119,
#   597.41434,
#   679.3119,
#   'Bouygues Immobilier s’engage, par exemple, à respecter les exigences'),
#  (2,
#   99.2126,
#   664.7722,
#   342.2909999999998,
#   672.7722,
#   'De façon générale, la prévention des risques environnementaux nécessite'),
#  (2,
#   354.3329,
#   660.3092,
#   597.40238,
#   668.3119,
#   'liées aux certiﬁ cations NF Habitat – NF Habitat HQE™ sur ses opérations'),
#  (2,
#   99.2126,
#   653.7722,
#   342.3023999999996,
#   661.7722,
#   'd’établir une analyse préalable, matérialisée par une cartographie ou une'),
#  (2,
#   354.33309999999994,
#   649.3092,
#   597.3795800000004,
#   657.3092,
#   'en logement (89,7 % du chiffre d’affaires) en s’appuyant sur un système'),
#  (2,
#   99.2126,
#   642.7722,
#   342.291,
#   650.7722,
#   'étude des risques environnementaux des sites de production ou des sites'),
#  (2,
#   354.33309999999994,
#   638.3092,
#   597.40466,
#   646.3092,
#   'de management audité chaque année par Cerqual Qualitel Certiﬁ cation'),
#  (2,
#   99.2126,
#   631.7722,
#   170.34859999999998,
#   639.7722,
#   'ﬁ xes liés aux activités.'),
#  (2,
#   354.33309999999994,
#   627.3092,
#   597.39022,
#   635.3092,
#   '(25 % des opérations sont vériﬁ ées en conception et à la livraison et doivent'),
#  (2,
#   99.2126,
#   617.9402,
#   342.3092400000005,
#   625.9402,
#   'Les principaux risques environnementaux des métiers sont énumérés au'),
#  (2,
#   354.33309999999994,
#   616.3092,
#   539.3106,
#   624.3092,
#   'répondre aux exigences du référentiel NF Habitat HQE™).'),
#  (2,
#   99.2126,
#   606.9402,
#   342.2872,
#   614.9402,
#   'chapitre 4 du présent document, dans les sections 4.1 Risques des métiers'),
#  (2,
#   354.33419999999995,
#   602.4772,
#   597.3821999999997,
#   610.4772,
#   'Aﬁ n de prévenir les risques environnementaux sur les sites ou chantiers'),
#  (2,
#   99.2126,
#   595.9402,
#   342.2864400000001,
#   603.9402,
#   'et 4.5 Plan de vigilance. Les risques ﬁ nanciers liés aux effets du changement'),
#  (2,
#   354.33419999999995,
#   591.4772,
#   597.4080400000001,
#   599.4772,
#   'de Colas et sur les chantiers de Bouygues Construction, ces deux'),
#  (2,
#   99.2126,
#   584.9402,
#   321.1173999999999,
#   592.9402,
#   'climatique sont quant à eux identiﬁ és et explicités dans la partie 4.2.'),
#  (2,
#   354.33419999999995,
#   580.4772,
#   597.40804,
#   588.4772,
#   'métiers s’appuient sur des systèmes de management environnementaux'),
#  (2,
#   354.33419999999995,
#   569.4772,
#   597.3837200000003,
#   577.4772,
#   'principalement issus de la norme Iso 14001. Ce système de management'),
#  (2,
#   354.33419999999995,
#   558.4772,
#   597.3935999999998,
#   566.4772,
#   'comprend une analyse des risques et des procédures permettant aux entités'),
#  (2,
#   99.2126,
#   558.3642000000001,
#   310.6225999999999,
#   568.3642000000001,
#   'Systèmes de management environnementaux'),
#  (2,
#   354.33419999999995,
#   547.4772,
#   560.2485999999999,
#   555.4772,
#   'de répondre aux enjeux environnementaux liés à leurs activités.'),
#  (2,
#   99.2126,
#   544.9296,
#   342.3183600000001,
#   552.9296,
#   'Inscrit dans la politique RSE de Bouygues, le déploiement d’un système de'),
#  (2,
#   99.2126,
#   533.9296,
#   342.27428,
#   541.9296,
#   'management environnemental est l’une des quatre actions que les métiers'),
#  (2,
#   99.2126,
#   507.1642,
#   276.25059999999996,
#   517.1642,
#   'Indicateurs de Bouygues Construction'),
#  (2, 218.05259999999998, 487.9893, 257.35659999999996, 495.9893, 'Périmètre'),
#  (2, 193.82059999999998, 478.3893, 257.3566, 486.3893, '(organisationnel'),
#  (2, 99.2126, 468.7893, 137.64860000000002, 476.7893, 'Indicateur'),
#  (2,
#   209.6206,
#   468.78929999999997,
#   308.97260000000006,
#   476.78929999999997,
#   'ou régional) Couverture'),
#  (2,
#   359.84459999999996,
#   468.78929999999997,
#   434.1406,
#   476.78929999999997,
#   '2017 Commentaire'),
#  (2,
#   325.3246,
#   468.78929999999997,
#   342.98859999999996,
#   476.78929999999997,
#   '2018'),
#  (2, 99.2126, 455.7354, 161.3474, 463.53540000000004, 'Part de l’activité'),
#  (2,
#   230.50080000000003,
#   455.6992,
#   255.14100000000002,
#   463.49920000000003,
#   'Monde'),
#  (2, 291.8439, 455.6992, 311.1684, 463.49920000000003, '98 %'),
#  (2,
#   326.01179999999994,
#   455.6836000000001,
#   342.9923999999999,
#   463.48360000000014,
#   '95 %'),
#  (2,
#   361.43159999999995,
#   455.6836000000001,
#   595.2521999999999,
#   463.48360000000014,
#   '91 % La maîtrise des impacts environnementaux des activités de'),
#  (2,
#   99.2126,
#   447.73260000000005,
#   180.5028,
#   457.84665700000005,
#   'couverte par un SME a'),
#  (2,
#   275.7486,
#   447.69640000000004,
#   311.16060000000004,
#   455.49640000000005,
#   'du chiffre'),
#  (2,
#   382.6787999999999,
#   447.68080000000015,
#   597.46272,
#   455.48080000000016,
#   'Bouygues Construction passe notamment par une politique'),
#  (2,
#   99.21120000000002,
#   439.73260000000005,
#   159.97320000000002,
#   447.53260000000006,
#   'certiﬁ é Iso 14001'),
#  (2,
#   277.1682,
#   439.69360000000006,
#   311.16060000000004,
#   447.4936000000001,
#   'd’affaires'),
#  (2,
#   382.6787999999999,
#   439.67800000000017,
#   578.4821999999999,
#   447.4780000000002,
#   'de prévention fondée sur un système de management'),
#  (2,
#   262.6212,
#   431.6908000000001,
#   311.16060000000004,
#   439.4908000000001,
#   'consolidé de'),
#  (2,
#   382.6787999999999,
#   431.6752000000002,
#   586.6012199999999,
#   439.4752000000002,
#   'environnemental certiﬁ é Iso 14001, très largement utilisé.'),
#  (2,
#   273.86879999999996,
#   423.6880000000001,
#   311.1606,
#   431.4880000000001,
#   'Bouygues'),
#  (2,
#   382.6787999999999,
#   423.6724000000002,
#   595.28496,
#   431.4724000000002,
#   'En 2018, 95 % de l’activité du g roupe est certiﬁ ée Iso 14001.'),
#  (2,
#   262.86299999999994,
#   415.6852000000001,
#   308.97659999999996,
#   423.48520000000013,
#   'Construction'),
#  (2,
#   99.2126,
#   401.4669,
#   242.73999999999998,
#   408.1669,
#   '(a) système de management de l’environnement'),
#  (2,
#   99.2126,
#   376.32500000000005,
#   342.2796000000001,
#   384.32500000000005,
#   'Chez Colas, la certiﬁ cation Iso 14001 est déployée sur plus de la moitié des'),
#  (2,
#   361.41459999999995,
#   376.3224,
#   597.39992,
#   384.3224,
#   'faibles nuisances. Il est également le garant du respect des mesures qui'),
#  (2,
#   99.21260000000001,
#   365.32500000000005,
#   342.2864399999999,
#   373.32500000000005,
#   'installations ﬁ xes et en particulier sur les sites de production de matériaux.'),
#  (2,
#   361.41459999999995,
#   365.3224,
#   597.4189200000004,
#   373.3224,
#   'ont été mises en place. Chaque corps d’état désigne aussi un responsable'),
#  (2,
#   99.21260000000001,
#   354.32500000000005,
#   342.2788399999999,
#   362.32500000000005,
#   'Un dispositif d’audits croisés annuels inter-ﬁ liales réalisés sur le périmètre'),
#  (2,
#   361.41459999999995,
#   354.3224,
#   543.9057999999999,
#   362.3224,
#   'Environnement, interlocuteur privilégié du coordinateur.'),
#  (2,
#   99.21260000000001,
#   343.32500000000005,
#   342.2879599999999,
#   351.32500000000005,
#   'Belgique/France métropolitaine/Suisse, par des auditeurs internes formés'),
#  (2,
#   354.3307,
#   339.5904,
#   597.4026200000001,
#   349.5904,
#   '• Les check-lists de Colas, qui couvrent chaque type d’installations ﬁ xes'),
#  (2,
#   99.21260000000001,
#   332.32500000000005,
#   342.2909999999999,
#   340.32500000000005,
#   'à cet effet, permet d’évaluer les installations et de renforcer la prévention :'),
#  (2,
#   361.4173,
#   329.49030000000005,
#   597.4239000000002,
#   337.49030000000005,
#   '(laboratoires, dépôts des centres de travaux, ateliers, postes d’enrobage à'),
#  (2,
#   99.21260000000001,
#   321.32500000000005,
#   342.3214000000001,
#   329.32500000000005,
#   'une centaine de sites certiﬁ és Iso 14001, soit environ 14 % des sites de la'),
#  (2,
#   361.4173,
#   318.49030000000005,
#   597.3897000000002,
#   326.49030000000005,
#   'chaud et à froid, usines d’émulsion et de liants, dépôts de bitume, carrières,'),
#  (2,
#   99.21260000000001,
#   310.32500000000005,
#   342.2606000000006,
#   318.32500000000005,
#   'zone, sont ainsi audités chaque année. Les enseignements de ces audits'),
#  (2,
#   361.4173,
#   307.49030000000005,
#   597.4238999999999,
#   315.49030000000005,
#   'gravières, plateformes de recyclage, centrales à béton et usines de'),
#  (2,
#   99.21260000000001,
#   299.32500000000005,
#   342.27883999999966,
#   307.32500000000005,
#   'croisés sont partagés avec le reste du Groupe, tandis que certains territoires'),
#  (2,
#   361.4173,
#   296.49030000000005,
#   597.3935000000002,
#   304.49030000000005,
#   'préfabrication, décharges du BTP, etc.), déﬁ nissent un référentiel concret'),
#  (2,
#   99.21260000000001,
#   288.32500000000005,
#   342.28036,
#   296.32500000000005,
#   'expérimentent des échanges dans le même esprit (o céan Indien, États-Unis,'),
#  (2,
#   361.4173,
#   285.49030000000005,
#   597.4094599999996,
#   293.49030000000005,
#   'd’évaluation de la performance environnementale. Les sites concernés'),
#  (2,
#   99.21260000000001,
#   276.404,
#   326.7916,
#   287.404,
#   'par exemple), souvent mis en œuvre à la suite du programme EOCE a.'),
#  (2,
#   361.4173,
#   274.49030000000005,
#   595.2958999999997,
#   282.49030000000005,
#   'représentent environ 2 800 unités de production réparties dans le monde.'),
#  (2,
#   354.3307,
#   259.7557,
#   597.3942599999997,
#   269.7557,
#   '• Lancée en 2017, la démarche Top Site a remplacé progressivement'),
#  (2,
#   99.2126,
#   250.75179999999997,
#   190.92260000000007,
#   260.7518,
#   'Démarches internes'),
#  (2,
#   361.4173,
#   249.6557,
#   597.4155399999997,
#   257.6557,
#   'la démarche Ecosite utilisée par Bouygues Construction jusqu’en'),
#  (2,
#   361.4173,
#   238.6557,
#   597.3851400000001,
#   246.6557,
#   'mai 2018. Dans une logique d’harmonisation et de simpliﬁ cation, le'),
#  (2,
#   99.2126,
#   237.31709999999998,
#   342.28568000000007,
#   245.31709999999998,
#   'Pour permettre une meilleure prise en compte des risques environnementaux'),
#  (2,
#   361.4173,
#   227.6557,
#   597.3927399999999,
#   235.6557,
#   'label Top Site a pris la suite depuis cette date. Ce label couvre toutes'),
#  (2,
#   99.2126,
#   226.31709999999998,
#   342.29859999999974,
#   234.31709999999998,
#   'spéciﬁ ques à leurs activités, les métiers du groupe Bouygues ont mis en place'),
#  (2,
#   361.4173,
#   216.6557,
#   597.42086,
#   224.6557,
#   'les thématiques du développement durable et permet la gestion'),
#  (2,
#   99.2126,
#   215.31709999999998,
#   334.55419999999987,
#   223.31709999999998,
#   'des systèmes de management et des labels environnementaux internes.'),
#  (2,
#   361.4173,
#   205.6557,
#   597.4185800000002,
#   213.6557,
#   'des impacts environnementaux et des pollutions sur les chantiers'),
#  (2,
#   99.2126,
#   200.58249999999998,
#   342.27008000000006,
#   210.58249999999998,
#   '• Bouygues Immobilier met en œuvre la charte des chantiers à faibles'),
#  (2,
#   361.4173,
#   194.6557,
#   597.4003400000003,
#   202.6557,
#   'de Bouygues Construction. Il inclut non seulement les critères'),
#  (2,
#   106.2992,
#   190.48239999999998,
#   342.28148,
#   198.48239999999998,
#   'nuisances sur l’ensemble des programmes d’immobilier d’entreprise'),
#  (2,
#   361.4173,
#   183.6557,
#   597.3874200000002,
#   191.6557,
#   'environnementaux mais aussi de nouveaux critères intégrant des'),
#  (2,
#   106.2992,
#   179.48239999999998,
#   342.2761599999998,
#   187.48239999999998,
#   '(10,3 % du chiffre d’affaires de Bouygues Immobilier) et sur les opérations'),
#  (2,
#   361.4173,
#   172.6557,
#   597.3790599999996,
#   180.6557,
#   'composantes sociale, sociétale, de Santé-Sécurité au travail, de qualité'),
#  (2,
#   106.2992,
#   168.48239999999998,
#   342.28387999999995,
#   176.48239999999998,
#   'de logements certiﬁ ées NF Habitat HQE™ représentant 25 % de ses projets'),
#  (2,
#   361.4173,
#   161.6557,
#   597.3934999999998,
#   169.6557,
#   'et aussi relatives à l’implication du client dans l’obtention du label. Du fait'),
#  (2,
#   106.2978,
#   157.48239999999998,
#   342.2595599999997,
#   165.48239999999998,
#   'de Logement (89,7 % du chiffre d’affaires). La charte implique la désignation,'),
#  (2,
#   361.4173,
#   150.6557,
#   597.40186,
#   158.6557,
#   'du déploiement de Top Site sur le second semestre 2018 seulement, peu'),
#  (2,
#   106.2978,
#   146.48239999999998,
#   342.28539999999975,
#   154.48239999999998,
#   'en amont des travaux, d’un coordinateur Environnement à la charge de'),
#  (2,
#   361.4173,
#   139.6557,
#   597.4231400000002,
#   147.6557,
#   'de chantiers sont déjà labellisés. L’ambition de Bouygues Construction est'),
#  (2,
#   106.2978,
#   135.48239999999998,
#   342.26260000000036,
#   143.48239999999998,
#   'l’entreprise de gros œuvre. Présent durant toute la durée du chantier,'),
#  (2,
#   361.4173,
#   128.6557,
#   595.2617000000004,
#   136.6557,
#   'd’établir Top Site comme standard commun à l’ensemble de ses chantiers.'),
#  (2,
#   106.2978,
#   124.48239999999998,
#   342.28691999999995,
#   132.48239999999998,
#   'son rôle est de collecter, stocker et classiﬁ er l’ensemble des données à'),
#  (2,
#   106.2978,
#   113.48239999999998,
#   342.26259999999996,
#   121.48239999999998,
#   'caractère environnemental nécessaires à l’organisation d’un chantier à'),
#  (2,
#   99.2126,
#   69.19380000000001,
#   270.41769999999997,
#   75.8938,
#   '(a) Environmental Officer correspondant Environnement'),
#  (2,
#   85.0394,
#   49.879599999999996,
#   264.3159000000002,
#   56.379599999999996,
#   '98 • BOUYGUES • DOCUMENT DE RÉFÉRENCE 2018'),
#  (3,
#   245.1104,
#   783.1738,
#   581.1054000000001,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (3, 443.1522, 770.3225, 580.9692, 779.3225, 'Informations environnementales'),
#  (3,
#   70.8661,
#   727.1279000000001,
#   228.9481000000001,
#   737.1279000000001,
#   'Indicateur Bouygues Construction'),
#  (3, 189.7061, 707.953, 229.0101, 715.953, 'Périmètre'),
#  (3, 165.4741, 698.353, 229.01010000000002, 706.353, '(organisationnel'),
#  (3, 70.8661, 688.7529999999999, 109.3021, 696.7529999999999, 'Indicateur'),
#  (3,
#   181.2741,
#   688.7529999999999,
#   280.62610000000006,
#   696.7529999999999,
#   'ou régional) Couverture'),
#  (3,
#   331.49809999999997,
#   688.7529999999999,
#   405.7941,
#   696.7529999999999,
#   '2017 Commentaire'),
#  (3,
#   296.9781,
#   688.7529999999999,
#   314.64209999999997,
#   696.7529999999999,
#   '2018'),
#  (3, 70.8661, 675.6990999999999, 138.4843, 683.4991, 'Part des chantiers'),
#  (3, 202.1551, 675.6679, 226.7953, 683.4679, 'Monde'),
#  (3, 263.4982, 675.6679, 282.8227, 683.4679, '98 %'),
#  (3,
#   336.0343,
#   675.6523000000001,
#   527.2201,
#   683.4523,
#   'n.a. Top Site est une nouvelle labellisation lancée en'),
#  (3, 294.1873, 675.6523000000001, 314.64669999999995, 683.4523, '11,3 %'),
#  (3, 70.8661, 667.6963, 139.6292064, 677.810357, 'labellisés Top Site a'),
#  (3, 247.4029, 667.6651, 282.8149, 675.4651, 'du chiffre'),
#  (3,
#   354.3331,
#   667.6495000000001,
#   545.3238999999999,
#   675.4495000000001,
#   'mai 2018 et remplace Ecosite. Elle couvre l’ensemble'),
#  (3, 248.8225, 659.6623000000001, 282.8149, 667.4623, 'd’affaires'),
#  (3,
#   354.3331,
#   659.6467000000001,
#   545.85742,
#   667.4467000000001,
#   'des thématiques de la RSE (santé et sécurité, qualité,'),
#  (3, 234.2755, 651.6595000000001, 282.8149, 659.4595, 'consolidé de'),
#  (3,
#   354.3331,
#   651.6439000000001,
#   556.2828999999999,
#   659.4439000000001,
#   'environnement, social et sociétal) et intègre dorénavant'),
#  (3, 245.5231, 643.6567000000001, 282.8149, 651.4567000000001, 'Bouygues'),
#  (3,
#   354.3331,
#   643.6411000000002,
#   539.2243,
#   651.4411000000001,
#   'des thématiques d’innovation. Ce label récemment'),
#  (3, 234.5173, 635.6539000000001, 280.6309, 643.4539000000001, 'Construction'),
#  (3,
#   354.3331,
#   635.6383000000002,
#   541.5097,
#   643.4383000000001,
#   'lancé couvre uniquement quatre mois de la période'),
#  (3,
#   354.3331,
#   627.6355000000002,
#   548.9196999999999,
#   635.4355000000002,
#   'de reporting, ce qui explique ce taux. Le déploiement'),
#  (3,
#   354.3331,
#   619.6327000000002,
#   548.4984999999999,
#   627.4327000000002,
#   'continuera en 2019 avec une ambition d’évaluation de'),
#  (3,
#   354.3331,
#   611.6299000000002,
#   442.6603,
#   619.4299000000002,
#   '100 % des sites éligibles.'),
#  (3,
#   70.8661,
#   597.4304999999999,
#   547.0485000000002,
#   604.1305,
#   '(a) Le pourcentage de chantiers labellisés Top Site se calcule en divisant le nombre de chantiers éligibles labellisés par la somme des chantiers éligibles (labellisés'),
#  (3,
#   80.78880000000001,
#   589.4306999999999,
#   544.7638000000006,
#   596.1306999999999,
#   'ou non). Les critères d’éligibilité font référence à des seuils de durée, d’activité et d’avancement du chantier, exception faite de Bouygues Energies & Services.'),
#  (3,
#   70.8661,
#   580.0104999999999,
#   129.8127,
#   586.7104999999999,
#   'n.a. : non applicable'),
#  (3, 70.8661, 551.8523, 150.53110000000004, 561.8523, 'Indicateurs Colas'),
#  (3, 302.6501, 532.6773999999999, 320.3141, 540.6773999999999, '2018'),
#  (3, 70.8661, 532.6773999999999, 109.3237, 540.6773999999999, 'Indicateur'),
#  (3,
#   195.40210000000002,
#   532.6773999999999,
#   286.3013000000001,
#   540.6773999999999,
#   'Périmètre Couverture'),
#  (3,
#   337.1701,
#   532.6773999999999,
#   411.46610000000004,
#   540.6773999999999,
#   '2017 Commentaire'),
#  (3, 70.8661, 519.6234999999999, 147.6181, 527.4235, 'Taux de certiﬁ cation'),
#  (3, 265.5327, 519.5923, 288.48810000000003, 527.3923, '100 %'),
#  (3, 207.8244, 519.5923, 232.4646, 527.3923, 'Monde'),
#  (3,
#   304.81739999999996,
#   519.5845000000002,
#   320.316,
#   527.3845000000001,
#   '61 %'),
#  (3,
#   337.359,
#   519.5845000000002,
#   568.6835999999998,
#   527.3845000000001,
#   '62 % Le taux de certiﬁ cation environnementale des activités de'),
#  (3,
#   70.8661,
#   511.6207,
#   186.86769999999999,
#   519.4207,
#   'environnementale des activités'),
#  (3, 244.6872, 511.5895, 288.48420000000004, 519.3895, 'du CAE des'),
#  (3,
#   360.00239999999997,
#   511.5817000000001,
#   557.2721999999999,
#   519.3817000000001,
#   'production de matériaux a baissé de 1 point mais reste'),
#  (3,
#   70.8661,
#   503.6179,
#   172.79649999999998,
#   511.41790000000003,
#   'de production de matériaux'),
#  (3,
#   244.95239999999998,
#   503.5867,
#   288.48420000000004,
#   511.3867,
#   'activités de'),
#  (3,
#   360.00239999999997,
#   503.57890000000015,
#   559.4562,
#   511.37890000000016,
#   'à un niveau satisfaisant compte tenu de la disparité des'),
#  (3, 70.8661, 496.538, 149.89610000000002, 503.538, 'en pourcentage de CAE'),
#  (3, 246.58259999999999, 495.5839, 288.4842, 503.38390000000004, 'production'),
#  (3,
#   360.00239999999997,
#   495.57610000000017,
#   557.3034,
#   503.3761000000002,
#   'contextes dans lesquels Colas opère dans le monde et'),
#  (3, 597.9988, 489.07212499999997, 616.5094479999999, 518.361125, '3'),
#  (3,
#   239.99939999999998,
#   487.58110000000005,
#   286.3002,
#   495.38110000000006,
#   'de matériaux'),
#  (3,
#   360.00239999999997,
#   487.5733000000002,
#   568.6679999999999,
#   495.3733000000002,
#   'des nombreuses participations minoritaires de Colas dans'),
#  (3,
#   360.00239999999997,
#   479.5705000000002,
#   550.5017999999999,
#   487.3705000000002,
#   'ces activités. Par ailleurs, dans certaines régions, des'),
#  (3,
#   360.00239999999997,
#   471.56770000000023,
#   564.3389999999998,
#   479.36770000000024,
#   'managers s’interrogent sur l’utilité d’une telle démarche,'),
#  (3,
#   360.00239999999997,
#   463.56490000000025,
#   547.0307999999999,
#   471.36490000000026,
#   'voire souhaitent substituer à celle-ci des règles plus'),
#  (3,
#   360.00239999999997,
#   455.56210000000027,
#   550.6655999999999,
#   463.3621000000003,
#   'pratiques et moins systémiques. À ce stade, le débat'),
#  (3,
#   360.00239999999997,
#   447.5593000000003,
#   546.8747999999998,
#   455.3593000000003,
#   'n’est pas tranché même si une tendance lourde des'),
#  (3,
#   360.00239999999997,
#   439.5565000000003,
#   550.7747999999999,
#   447.3565000000003,
#   'ﬁ liales à ajuster plus ﬁ nement le périmètre certiﬁ é de'),
#  (3,
#   360.00239999999997,
#   431.55370000000033,
#   481.76039999999995,
#   439.35370000000034,
#   'leurs activités peut être observée.'),
#  (3, 207.8244, 418.4867, 232.4646, 426.2867, 'Monde'),
#  (3, 265.5327, 418.4867, 288.48810000000003, 426.2867, '100 %'),
#  (3,
#   70.87200000000001,
#   418.48090000000036,
#   155.6736,
#   426.2809000000004,
#   'Taux d’auto-évaluation'),
#  (3,
#   303.27299999999997,
#   418.4633000000002,
#   320.31443999999993,
#   426.2633000000002,
#   '83 %'),
#  (3,
#   337.14606,
#   418.4633000000002,
#   565.59246,
#   426.2633000000002,
#   '85 % Malgré une amélioration de la performance en Métropole'),
#  (3, 244.6872, 410.4839, 288.48420000000004, 418.2839, 'du CAE des'),
#  (3,
#   70.87200000000001,
#   410.4781000000004,
#   152.8968,
#   418.2781000000004,
#   'environnementale par'),
#  (3,
#   360.00239999999997,
#   410.4605000000002,
#   532.41048,
#   418.2605000000002,
#   'et des efforts continus à l’International, le taux a'),
#  (3,
#   244.95239999999998,
#   402.4811,
#   288.48420000000004,
#   410.28110000000004,
#   'activités de'),
#  (3,
#   70.87200000000001,
#   402.4753000000004,
#   133.1788,
#   412.629257,
#   'checklists a Colas'),
#  (3,
#   360.00239999999997,
#   402.4577000000002,
#   551.5157999999998,
#   410.2577000000002,
#   'globalement baissé cette année. Il se situe toujours à'),
#  (3, 70.8661, 395.4324, 147.9361, 402.4324, 'en pourcentage de CAE'),
#  (3,
#   246.58259999999999,
#   394.47830000000005,
#   288.4842,
#   402.27830000000006,
#   'production'),
#  (3,
#   360.00239999999997,
#   394.45490000000024,
#   546.4535999999999,
#   402.25490000000025,
#   'un niveau élevé. La baisse observée à l’international'),
#  (3,
#   239.99939999999998,
#   386.47550000000007,
#   288.4842,
#   394.2755000000001,
#   'de matériaux'),
#  (3,
#   360.00239999999997,
#   386.45210000000026,
#   564.2687999999999,
#   394.25210000000027,
#   's’explique notamment par l’augmentation du nombre de'),
#  (3,
#   269.55359999999996,
#   378.4727000000001,
#   288.4842,
#   386.2727000000001,
#   'pour'),
#  (3,
#   360.00239999999997,
#   378.4493000000003,
#   473.03219999999993,
#   386.2493000000003,
#   'sites industriels pris en compte.'),
#  (3,
#   242.96339999999995,
#   370.4699000000001,
#   288.4842,
#   378.2699000000001,
#   'lesquelles la'),
#  (3,
#   239.42999999999995,
#   362.46710000000013,
#   288.4842,
#   370.26710000000014,
#   'check-list est'),
#  (3,
#   249.04739999999995,
#   354.46430000000015,
#   286.3001999999999,
#   362.26430000000016,
#   'applicable'),
#  (3, 265.5327, 341.3812, 288.48810000000003, 349.1812, '100 %'),
#  (3, 207.8244, 341.3812, 232.4646, 349.1812, 'Monde'),
#  (3,
#   70.87200000000001,
#   341.3759000000003,
#   151.68,
#   349.1759000000003,
#   'Ratio des activités de'),
#  (3,
#   303.25739999999996,
#   341.37340000000006,
#   320.3159999999999,
#   349.1734000000001,
#   '84 %'),
#  (3,
#   337.1484,
#   341.37340000000006,
#   555.3144,
#   349.1734000000001,
#   '85 % L’indicateur se maintient à un niveau élevé même si ce'),
#  (3, 244.6872, 333.3784, 288.48420000000004, 341.1784, 'du CAE des'),
#  (3,
#   70.87200000000001,
#   333.3731000000003,
#   163.43460000000002,
#   341.1731000000003,
#   'production de matériaux'),
#  (3,
#   360.00239999999997,
#   333.3706000000001,
#   562.85544,
#   341.1706000000001,
#   'taux a baissé de 1 point en 2018. Même s’il est ambitieux'),
#  (3,
#   244.95239999999998,
#   325.3756,
#   288.48420000000004,
#   333.17560000000003,
#   'activités de'),
#  (3,
#   70.87200000000001,
#   325.3703000000003,
#   176.016,
#   333.17030000000034,
#   'dotées d’un outil de gestion'),
#  (3,
#   360.00239999999997,
#   325.3678000000001,
#   540.8727,
#   333.1678000000001,
#   'compte tenu de la présence dans certaines ﬁ liales'),
#  (3,
#   246.58259999999999,
#   317.37280000000004,
#   288.4842,
#   325.17280000000005,
#   'production'),
#  (3,
#   70.87200000000001,
#   317.36750000000035,
#   186.92819999999998,
#   325.16750000000036,
#   'des impacts environnementaux'),
#  (3,
#   360.00239999999997,
#   317.3650000000001,
#   547.5924,
#   325.16500000000013,
#   'd’autres actionnaires parfois majoritaires, l’objectif à'),
#  (3,
#   239.99939999999998,
#   309.37000000000006,
#   286.3002,
#   317.1700000000001,
#   'de matériaux'),
#  (3,
#   70.87200000000001,
#   309.36470000000037,
#   187.6068,
#   317.1647000000004,
#   '(certiﬁ cation environnementale'),
#  (3,
#   360.00239999999997,
#   309.36220000000014,
#   457.90799999999996,
#   317.16220000000015,
#   'atteindre reste ﬁ xé à 100 %.'),
#  (3,
#   70.87200000000001,
#   301.3619000000004,
#   153.8094,
#   309.1619000000004,
#   'et/ou check-list Colas)'),
#  (3, 70.8661, 294.3268, 147.9361, 301.3268, 'en pourcentage de CAE'),
#  (3,
#   70.8661,
#   279.94399999999996,
#   533.2666000000006,
#   286.64399999999995,
#   '(a) activités pour lesquelles la check-list est applicable : carrière permanente ; gravière permanente ; banc d’emprunt ; poste d’enrobage à chaud ﬁ xe ; poste'),
#  (3,
#   80.78880000000001,
#   271.94419999999997,
#   529.7357,
#   278.64419999999996,
#   'd’enrobage à froid ﬁ xe ; rafﬁ nerie de pétrole et bitume ; usine d’asphalte ; usine de liants, émulsions et/ou liants modiﬁ és ﬁ xes ; centrale béton ; usine de'),
#  (3,
#   80.78879999999998,
#   263.9444,
#   547.4036000000007,
#   270.64439999999996,
#   'préfabrication ﬁ xe ; recyclage ﬁ xe ; usine de membranes bitumineuses ; fabrications et installations diverses ﬁ xes ; dépôt de liants bitumineux ﬁ xes. Ceci exclut'),
#  (3,
#   80.78879999999998,
#   255.94459999999998,
#   462.66870000000097,
#   262.64459999999997,
#   'certaines activités industrielles très spéciﬁ ques et peu importantes en volume (production de charpente métallique, par exemple).'),
#  (3,
#   70.86609999999997,
#   246.52439999999999,
#   174.39449999999994,
#   253.2244,
#   'CAE : chiffre d’activité économique'),
#  (3,
#   325.9829,
#   221.0467,
#   569.0613,
#   229.0467,
#   'en 2018 plus de 84 sessions (une douzaine de participants en moyenne par'),
#  (3,
#   70.8661,
#   217.0777,
#   304.5421000000002,
#   229.0777,
#   '3.3.1.3 Formation et sensibilisation en faveur'),
#  (3,
#   325.9829,
#   209.97469999999998,
#   443.7297,
#   217.97469999999998,
#   'session) depuis sa création en 2006.'),
#  (3,
#   110.5501,
#   203.5417,
#   291.66610000000003,
#   215.5417,
#   'de la protection de l’environnement'),
#  (3,
#   325.9829,
#   196.0707,
#   569.0514200000001,
#   204.0707,
#   'En complément, l a formation de l’Institut de management Bouygues (IMB),'),
#  (3,
#   325.9829,
#   184.99869999999999,
#   569.06434,
#   192.99869999999999,
#   'dont la thématique s’intitule “Vers l’entreprise contributive” et destinée'),
#  (3,
#   70.8661,
#   181.75629999999998,
#   313.95058000000034,
#   189.75629999999998,
#   'Le groupe Bouygues déploie de nombreux programmes de formation et/ou'),
#  (3,
#   325.9829,
#   173.92669999999998,
#   569.0529399999998,
#   181.92669999999998,
#   'aux cadres dirigeants des cinq métiers de Bouygues, aborde les grands'),
#  (3,
#   70.8661,
#   170.22029999999998,
#   313.92626000000024,
#   178.22029999999998,
#   'de sensibilisation sur les enjeux de la protection de l’environnement auprès'),
#  (3,
#   325.9829,
#   162.85469999999998,
#   569.06054,
#   170.85469999999998,
#   'enjeux liés aux mutations sociétales qui induisent l’évolution des modèles'),
#  (3,
#   70.8661,
#   158.68429999999998,
#   205.79649999999995,
#   166.68429999999998,
#   'de ses collaborateurs et publics externes.'),
#  (3,
#   325.9829,
#   151.78269999999998,
#   569.0613000000002,
#   159.78269999999998,
#   'économiques du Groupe. Les sept sessions organisées en 2018 ont réuni'),
#  (3,
#   325.9829,
#   140.71069999999997,
#   415.23274000000004,
#   148.71069999999997,
#   'environ soixante managers.'),
#  (3,
#   70.8661,
#   131.5648,
#   296.7960999999999,
#   141.5648,
#   'Formation et sensibilisation au niveau du Groupe'),
#  (3,
#   325.9829,
#   126.80669999999998,
#   569.0658600000002,
#   134.80669999999998,
#   'Cette année, lors du conseil de Groupe de mai 2018, la thématique de'),
#  (3,
#   70.8661,
#   117.5907,
#   313.9194200000002,
#   125.5907,
#   'La direction centrale Développement durable-QSE organise des séminaires'),
#  (3,
#   325.9829,
#   115.73469999999998,
#   569.0628199999999,
#   123.73469999999998,
#   'l’économie circulaire a été abordée : sensibilisation des managers à'),
#  (3,
#   70.8661,
#   106.0547,
#   313.93537999999984,
#   114.0547,
#   'aﬁ n de former les managers du Groupe à auto-évaluer leurs pratiques de'),
#  (3,
#   325.9829,
#   104.66269999999997,
#   569.0468600000003,
#   112.66269999999997,
#   'l’épuisement des ressources et à la journée de dépassement de la terre,'),
#  (3,
#   70.86610000000002,
#   94.5187,
#   313.93462,
#   102.5187,
#   'management et à se situer par rapport aux meilleures pratiques déﬁ nies'),
#  (3,
#   325.9829,
#   93.59069999999997,
#   569.06586,
#   101.59069999999997,
#   'présentation du modèle des sept piliers de l’économie circulaire de'),
#  (3,
#   70.86610000000002,
#   82.9827,
#   313.9688200000001,
#   90.9827,
#   'par le modèle EFQM (European Foundation for Quality Management) et la'),
#  (3,
#   325.9829,
#   82.5047,
#   569.0646400000002,
#   92.627557,
#   'l’Ademe a, exemples externes, focus sur les projets exemplaires du Groupe et'),
#  (3,
#   70.86610000000002,
#   71.44669999999999,
#   313.91942000000034,
#   79.44669999999999,
#   'norme Iso 26000. Dénommé Abby, ce programme de séminaires totalise'),
#  (3,
#   325.9832,
#   71.4327,
#   566.9313199999997,
#   79.4327,
#   'table- ronde sur les perspectives du Groupe en matière d’économie circulaire.'),
#  (3,
#   70.8661,
#   58.6443,
#   255.2903,
#   65.3443,
#   '(a) Agence de l’environnement et de la maîtrise de l’énergie'),
#  (3,
#   402.6812,
#   49.8277,
#   581.6717000000001,
#   56.5552,
#   'BOUYGUES • DOCUMENT DE RÉFÉRENCE 2018 • 99'),
#  (4,
#   99.2126,
#   783.1738,
#   435.2076,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (4,
#   74.6853,
#   769.213125,
#   237.02960000000002,
#   798.502125,
#   '3 Informations environnementales'),
#  (4,
#   99.2126,
#   729.1439,
#   342.2757999999998,
#   737.1439,
#   'Enﬁ n, depuis son lancement en 2015, Yammer Bouygues, réseau collaboratif'),
#  (4,
#   354.3307,
#   728.2439,
#   597.4132600000002,
#   738.2439,
#   '• La “Semaine européenne du développement durable” (SEDD) et/ou'),
#  (4,
#   99.21260000000001,
#   718.1439,
#   342.2871999999997,
#   726.1439,
# ...
#  (8,
#   99.20889999999997,
#   236.16150000000005,
#   182.4973,
#   243.96150000000003,
#   'Taux de recyclage des'),
#  (8, 230.5015, 236.1371, 255.14794, 243.93710000000002, 'Monde'),
#  (8, 266.6194, 236.1371, 311.16286, 243.93710000000002, 'Activités de'),
#  (8, 327.38530000000003, 236.1293, 342.9931, 243.9293, '15 %'),
#  (8,
#   361.40110000000004,
#   236.1293,
#   583.3189,
#   243.9293,
#   '15 % Ce taux est resté stable en 2018 : la quantité d’agrégats'),
#  (8,
#   99.20889999999997,
#   228.15870000000004,
#   172.3339,
#   235.95870000000002,
#   'agrégats d’enrobés'),
#  (8, 269.2597, 228.1343, 311.16130000000004, 235.9343, 'production'),
#  (8,
#   382.6795,
#   228.1265,
#   583.2877,
#   235.9265,
#   'd’enrobés recyclés a augmenté de 2 % et la production'),
#  (8,
#   99.20889999999997,
#   220.15590000000003,
#   171.04689999999997,
#   227.9559,
#   'pour en valoriser le'),
#  (8, 262.67650000000003, 220.1315, 308.9773, 227.9315, 'de matériaux'),
#  (8,
#   382.6795,
#   220.12369999999999,
#   559.2949,
#   227.9237,
#   'd’enrobés de 5 %, ces variations favorables étant'),
#  (8,
#   99.20889999999997,
#   212.15310000000002,
#   129.6736094,
#   222.279657,
#   'bitume b'),
#  (8,
#   382.6795,
#   212.12089999999998,
#   567.7033,
#   219.9209,
#   'insufﬁ santes toutefois pour faire évoluer l’indicateur.'),
#  (8,
#   99.21190000000001,
#   199.04809999999998,
#   175.63630000000003,
#   206.84809999999996,
#   'Surface de chaussée'),
#  (8, 230.5015, 199.0316, 255.14794, 206.8316, 'Monde'),
#  (8, 266.6194, 199.0316, 311.16286, 206.8316, 'Activités de'),
#  (8, 332.5879, 199.0316, 342.9931, 206.8316, '3,3'),
#  (8,
#   366.4945,
#   199.0316,
#   589.7188,
#   206.8316,
#   '3,6 La surface de chaussées recyclées en place par les ﬁ liales'),
#  (8,
#   99.21190000000001,
#   191.04529999999997,
#   163.2187,
#   198.84529999999995,
#   'recyclée en place'),
#  (8, 276.4903, 191.0288, 308.97729999999996, 198.8288, 'chantiers'),
#  (8,
#   382.67949999999996,
#   191.0288,
#   577.6326999999999,
#   198.8288,
#   'Colas est en baisse de 4 % en 2018 par rapport à 2017.'),
#  (8, 99.2126, 183.9772, 153.79146899999998, 190.9772, 'en millions de m2'),
#  (8,
#   382.67949999999996,
#   183.02599999999998,
#   578.9118999999998,
#   190.826,
#   'L’augmentation de 5 % de cet indicateur dans les pays'),
#  (8,
#   382.67949999999996,
#   175.02319999999997,
#   583.5684999999999,
#   182.82319999999999,
#   'couverts par la direction générale internationale n’a pas'),
#  (8,
#   382.67949999999996,
#   167.02039999999997,
#   595.1437,
#   174.82039999999998,
#   'permis de compenser la baisse des ﬁ liales canadiennes qui'),
#  (8,
#   382.67949999999996,
#   159.01759999999996,
#   592.0470999999999,
#   166.81759999999997,
#   'avaient réalisé plus d’un tiers de cette production en 2017.'),
#  (8,
#   382.67949999999996,
#   151.01479999999995,
#   573.83956,
#   158.81479999999996,
#   'La diminution constatée au Canada en 2018 est liée à'),
#  (8,
#   382.67949999999996,
#   143.01199999999994,
#   567.0402999999999,
#   150.81199999999995,
#   'l’achèvement de chantiers utilisant cette technique.'),
#  (8,
#   99.2126,
#   128.7942,
#   569.1975000000003,
#   135.4942,
#   '(a) L’industrie estime que le taux de recyclage des agrégats d’enrobés à atteindre (pour pouvoir considérer que l’ensemble des enrobés excavés ou fraisés sont'),
#  (8,
#   109.1353,
#   120.79440000000001,
#   570.0015000000009,
#   127.49440000000001,
#   'recyclés) se situe entre 20 % et 25 % dans les pays de l’OCDE, ce taux étant lui-même variable localement en fonction de la densité urbaine et des habitudes'),
#  (8,
#   109.1353,
#   112.79460000000002,
#   592.1718000000005,
#   119.49460000000002,
#   'techniques des maîtres d’ouvrage. Colas se situe donc aux trois quarts de ce plafond et l’atteint en 2016 dans certaines ﬁ liales en Belgique, en Suisse, en France, aux'),
#  (8,
#   109.1353,
#   104.79480000000002,
#   445.5959,
#   111.49480000000003,
#   'États-Unis ou au Canada, tandis que cette politique progresse plus difﬁ cilement dans des pays moins volontaristes.'),
#  (8,
#   99.21259999999995,
#   95.37460000000003,
#   350.1008000000002,
#   102.07460000000003,
#   '(b) i ndicateur 2018 bénéﬁ ciant d’un niveau d’assurance raisonnable de la part de l’OTI'),
#  (8,
#   99.2126,
#   79.11500000000001,
#   252.2138,
#   85.815,
#   '(a) Bureau de recherches géologiques et minières'),
#  (8,
#   99.2126,
#   69.69480000000001,
#   453.8369000000002,
#   76.3948,
#   '(b) Ces aspects sont bien identiﬁ és à l’issue des analyses de cycle de vie (ACV) et des calculs d’empreinte carbone.'),
#  (8,
#   85.0394,
#   49.879599999999996,
#   267.9234000000002,
#   56.379599999999996,
#   '104 • BOUYGUES • DOCUMENT DE RÉFÉRENCE 2018'),
#  (9,
#   245.1104,
#   783.1738,
#   581.1054000000001,
#   794.1738,
#   'DÉCLARATION DE PERFORMANCE EXTRA-FINANCIÈRE (DPEF)'),
#  (9, 443.1522, 770.3225, 580.9692, 779.3225, 'Informations environnementales'),
#  (9,
#   70.8661,
#   727.1279000000001,
#   146.08410000000003,
#   737.1279000000001,
#   'Indicateur Colas'),
#  (9, 189.7061, 707.953, 229.0101, 715.953, 'Périmètre'),
#  (9, 165.4741, 698.353, 229.01010000000002, 706.353, '(organisationnel'),
#  (9,
#   296.9781,
#   688.7529999999999,
#   314.64209999999997,
#   696.7529999999999,
#   '2018'),
#  (9, 70.8661, 688.7529999999999, 109.3021, 696.7529999999999, 'Indicateur'),
#  (9,
#   181.2741,
#   688.7529999999999,
#   280.62610000000006,
#   696.7529999999999,
#   'ou régional) Couverture'),
#  (9,
#   331.49809999999997,
#   688.7529999999999,
#   405.7941,
#   696.7529999999999,
#   '2017 Commentaire'),
#  (9, 70.8661, 675.6990999999999, 150.2311, 683.4991, 'Taux de récupération'),
#  (9, 297.6667, 675.6679, 314.6473, 683.4679, '65 %'),
#  (9, 202.15570000000002, 675.6679, 226.80214000000004, 683.4679, 'Monde'),
#  (9, 244.88800000000003, 675.6679, 282.8217400000001, 683.4679, 'Toutes les'),
#  (9,
#   333.1645,
#   675.6679,
#   549.5052999999999,
#   683.4679,
#   '61 % Les huiles usées (hydrauliques et lubriﬁ cation moteur),'),
#  (9, 70.8661, 667.6963, 129.52210000000002, 675.4963, 'des huiles usées'),
#  (9, 250.8745, 667.6651, 280.6315, 675.4651, 'activités'),
#  (9,
#   354.33369999999996,
#   667.6651,
#   560.4721,
#   675.4651,
#   'principaux “déchets dangereux” générés par les activités'),
#  (9,
#   354.33369999999996,
#   659.6623000000001,
#   546.319,
#   667.4623,
#   'de Colas, ont vocation à être éliminées par une ﬁ lière'),
#  (9,
#   354.3337,
#   651.6595000000001,
#   518.1025,
#   659.4595,
#   'agréée ou valorisées de manière responsable.'),
#  (9,
#   354.3337,
#   643.6567000000001,
#   553.2961,
#   651.4567000000001,
#   'On peut considérer que l’optimum de cet indicateur se'),
#  (9,
#   354.3337,
#   635.6539000000001,
#   547.0482999999999,
#   643.4539000000001,
#   'situe autour de 80 % si la consommation/combustion'),
#  (9,
#   354.3337,
#   627.6511000000002,
#   561.3613,
#   635.4511000000001,
#   'd’huiles des engins et véhicules est incluse. Colas obtient'),
#  (9,
#   354.3337,
#   619.6483000000002,
#   516.9715,
#   627.4483000000001,
#   'un taux en augmentation de 4 points en 2018.'),
#  (9,
#   70.8661,
#   575.4743000000001,
#   233.39610000000013,
#   585.4743000000001,
#   'Indicateurs Bouygues Construction'),
#  (9, 189.7061, 556.2994, 229.0101, 564.2994, 'Périmètre'),
#  (9, 165.4741, 546.6994, 229.01010000000002, 554.6994, '(organisationnel'),
#  (9, 296.9781, 537.0994, 314.64209999999997, 545.0994, '2018'),
#  (9, 70.8661, 537.0994, 109.3021, 545.0994, 'Indicateur'),
#  (9,
#   181.2741,
#   537.0994,
#   280.62610000000006,
#   545.0994,
#   'ou régional) Couverture'),
#  (9, 331.49809999999997, 537.0994, 405.7941, 545.0994, '2017 Commentaire'),
#  (9, 70.8661, 524.0455999999999, 150.1609, 531.8456, 'Part des déchets non'),
#  (9, 202.15570000000002, 524.0144, 226.78030000000004, 531.8144, 'Monde'),
#  (9,
#   264.55570000000006,
#   524.0066000000002,
#   282.8155000000001,
#   531.8066000000001,
#   '77 %'),
#  (9,
#   297.4639000000001,
#   523.9910000000002,
#   314.6473000000001,
#   531.7910000000002,
#   '58 %'),
#  (9,
#   331.82290000000006,
#   523.9910000000002,
#   566.8603,
#   531.7910000000002,
#   '63 % Bouygues Construction est engagée dans une politique de'),
#  (9,
#   70.8661,
#   516.0427999999999,
#   141.80710000000002,
#   523.8428,
#   'dangereux recyclés'),
#  (9,
#   179.42650000000003,
#   516.0116,
#   228.95650000000003,
#   523.8116,
#   'hors activités'),
#  (9,
#   247.40350000000007,
#   516.0038000000002,
#   282.8155000000001,
#   523.8038000000001,
#   'du chiffre'),
#  (9,
#   354.3337000000001,
#   515.9882000000002,
#   565.6044999999999,
#   523.7882000000002,
#   'valorisation de ses déchets et veille à utiliser des systèmes'),
#  (9,
#   168.56110000000004,
#   508.0088,
#   228.95650000000003,
#   515.8088,
#   'de terrassement'),
#  (9,
#   248.82310000000007,
#   508.00100000000015,
#   282.8155000000001,
#   515.8010000000002,
#   'd’affaires'),
#  (9,
#   354.3337000000001,
#   507.9854000000002,
#   561.3925,
#   515.7854000000002,
#   'de traçabilité, responsabilisant ainsi les collaborateurs sur'),
#  (9,
#   182.18770000000004,
#   500.00600000000003,
#   228.95650000000003,
#   507.80600000000004,
#   'et Bouygues'),
#  (9,
#   234.27610000000007,
#   499.99820000000017,
#   282.8155000000001,
#   507.7982000000002,
#   'consolidé de'),
#  (9,
#   354.3337000000001,
#   499.9826000000002,
#   561.5095,
#   507.78260000000023,
#   'les conditions dans lesquelles les déchets non dangereux'),
#  (9,
#   164.41150000000005,
#   492.00320000000005,
#   226.77406000000008,
#   499.80320000000006,
#   'E nergies & Services'),
#  (9,
#   245.52370000000008,
#   491.9954000000002,
#   282.8155000000001,
#   499.7954000000002,
#   'Bouygues'),
#  (9,
#   354.3337000000001,
#   491.97980000000024,
#   558.9511,
#   499.77980000000025,
#   'sont collectés, transportés et valorisés. La baisse du taux'),
#  (9, 597.9988, 489.07212499999997, 616.5094479999999, 518.361125, '3'),
#  (9,
#   234.51790000000008,
#   483.9926000000002,
#   280.6315000000001,
#   491.7926000000002,
#   'Construction'),
#  (9,
#   354.3337000000001,
#   483.97700000000026,
#   543.0781,
#   491.77700000000027,
#   's’explique par un changement de méthodologie, les'),
#  (9,
#   354.3337000000001,
#   475.9742000000003,
#   550.0435,
#   483.7742000000003,
#   'déblais n’étant plus comptabilisés dans cet indicateur.'),
#  (9,
#   354.3337000000001,
#   467.9714000000003,
#   550.5988600000002,
#   475.7714000000003,
#   'Bouygues Travaux Publics, qui s’attache à valoriser une'),
#  (9,
#   354.3337000000001,
#   459.9686000000003,
#   553.3273,
#   467.76860000000033,
#   'grande partie de ses déblais, représentait une part très'),
#  (9,
#   354.3337000000001,
#   451.96580000000034,
#   458.5495000000001,
#   459.76580000000035,
#   'importante de cet indicateur.'),
#  (9,
#   354.3337000000001,
#   443.96300000000036,
#   564.9649,
#   451.7630000000004,
#   'C’est un sujet majeur pour Bouygues Construction comme'),
#  (9,
#   354.3337000000001,
#   435.9602000000004,
#   564.4267,
#   443.7602000000004,
#   'en atteste d’ailleurs la valorisation de 80 % de ses déchets'),
#  (9,
#   354.3337000000001,
#   427.9574000000004,
#   481.37230000000005,
#   435.7574000000004,
#   'de chantier sur le périmètre France.'),
#  (9,
#   70.86610000000007,
#   414.88460000000043,
#   159.1465000000001,
#   422.68460000000044,
#   'Pourcentage de déblais'),
#  (9,
#   202.15570000000008,
#   414.8534000000004,
#   226.7803000000001,
#   422.65340000000043,
#   'Monde'),
#  (9,
#   263.65870000000007,
#   414.84560000000045,
#   282.8155000000001,
#   422.64560000000046,
#   '26 %'),
#  (9,
#   298.24390000000005,
#   414.83000000000055,
#   314.64730000000003,
#   422.63000000000056,
#   '73 %'),
#  (9,
#   331.7137000000001,
#   414.83000000000055,
#   561.2053000000001,
#   422.63000000000056,
#   '66 % Les déblais représentent la majorité des déchets générés'),
#  (9,
#   70.86610000000007,
#   406.88180000000045,
#   102.40150000000008,
#   414.68180000000046,
#   'valorisés'),
#  (9,
#   199.52710000000008,
#   406.85060000000044,
#   228.9565000000001,
#   414.65060000000045,
#   'Activité'),
#  (9,
#   247.40350000000007,
#   406.84280000000047,
#   282.8155000000001,
#   414.6428000000005,
#   'du chiffre'),
#  (9,
#   354.3337,
#   406.8272000000006,
#   532.99036,
#   414.6272000000006,
#   'par Bouygues Travaux Publics du fait des activités'),
#  (9,
#   172.18810000000008,
#   398.84780000000046,
#   226.7725000000001,
#   406.6478000000005,
#   'Travaux publics'),
#  (9,
#   248.82310000000007,
#   398.8400000000005,
#   282.8155000000001,
#   406.6400000000005,
#   'd’affaires'),
#  (9,
#   354.3337,
#   398.8244000000006,
#   543.6553,
#   406.6244000000006,
#   'd’excavation, tunnel et terrassement. Il faut observer'),
#  (9,
#   234.27610000000007,
#   390.8372000000005,
#   282.8155000000001,
#   398.6372000000005,
#   'consolidé de'),
#  (9,
#   354.3337,
#   390.8216000000006,
#   533.9911,
#   398.6216000000006,
#   'une nette amélioration de la performance en 2018'),
#  (9,
#   245.52370000000008,
#   382.8344000000005,
#   282.8155000000001,
#   390.63440000000054,
#   'Bouygues'),
#  (9,
#   354.3337,
#   382.81880000000064,
#   539.7475,
#   390.61880000000065,
#   'due à l’unité opérationnelle Bouygues Construction'),
#  (9,
#   234.51790000000008,
#   374.83160000000055,
#   280.6315000000001,
#   382.63160000000056,
#   'Construction'),
#  (9,
#   354.3337,
#   374.81600000000066,
#   549.1855,
#   382.61600000000067,
#   'Australia qui contribue en grande partie au résultat de'),
#  (9,
#   354.3337,
#   366.8132000000007,
#   552.6409,
#   374.6132000000007,
#   'valorisation. Cette unité opérationnelle représente plus'),
#  (9,
#   354.3337,
#   358.8104000000007,
#   553.9357,
#   366.6104000000007,
#   'de la moitié de la quantité totale de déblais produits et'),
#  (9,
#   354.3337,
#   350.8076000000007,
#   555.7999,
#   358.60760000000073,
#   'atteint une valorisation de 98 % du fait notamment de la'),
#  (9,
#   354.3337,
#   342.80480000000074,
#   450.32050000000004,
#   350.60480000000075,
#   'réglementation en vigueur.'),
#  (9,
#   325.98199999999997,
#   315.28290000000004,
#   569.0284800000001,
#   323.28290000000004,
#   'Brézillon a mis en place un di spositif de gestion des terres polluées avec la'),
#  (9,
#   70.8661,
#   313.26959999999997,
#   163.88610000000006,
#   323.26959999999997,
#   'Dépollution des sols'),
#  (9,
#   325.98199999999997,
#   304.28290000000004,
#   569.06192,
#   312.28290000000004,
#   'création en février 2017 d’une plateforme de transit, tri et valorisation des'),
#  (9,
#   70.8661,
#   299.8349,
#   313.94601999999963,
#   307.8349,
#   'Le groupe Bouygues, à travers ses ﬁ liales Colas Environnement et Brézillon,'),
#  (9,
#   325.98199999999997,
#   293.28290000000004,
#   569.0543199999998,
#   301.28290000000004,
#   'terres polluées. Fin 2018, la plateforme avait totalisé la prise en charge de'),
#  (9,
#   70.8661,
#   288.8349,
#   313.9634999999998,
#   296.8349,
#   'propose des solutions de dépollution des sols. Avec plus de 1 000 chantiers'),
#  (9,
#   325.98199999999997,
#   282.28290000000004,
#   569.05736,
#   290.28290000000004,
#   'près de 105 000 tonnes de terres polluées, dont 45 000 tonnes en 2017 et'),
#  (9,
#   70.8661,
#   277.8349,
#   313.9452600000003,
#   285.8349,
#   'réalisés, Colas Environnement dispose de références dans la plupart'),
#  (9,
#   325.98199999999997,
#   271.28290000000004,
#   569.0603999999998,
#   279.28290000000004,
#   '60 000 tonnes en 2018. Dès réception et contrôle, les matériaux sont triés'),
#  (9,
#   70.8661,
#   266.8349,
#   313.95210000000037,
#   274.8349,
#   'des techniques de dépollution ; la ﬁ liale est notamment reconnue pour'),
#  (9,
#   325.98199999999997,
#   260.28290000000004,
#   569.0436799999997,
#   268.28290000000004,
#   'et analysés par un bureau de contrôle externe, les matériaux inertes sont'),
#  (9,
#   70.8661,
#   255.83489999999998,
#   314.11549999999994,
#   263.8349,
#   'l’excellence et la ﬁ abilité de ses systèmes de traitement in situ, mais se'),
#  (9,
#   325.98199999999997,
#   249.2829,
#   569.0611600000003,
#   257.28290000000004,
#   'alors valorisés sur les chantiers de construction et les matériaux renfermant'),
#  (9,
#   70.86609999999999,
#   244.83489999999998,
#   313.96274000000034,
#   252.83489999999998,
#   'distingue aussi par sa politique de transparence. Elle est la première société'),
#  (9,
#   325.98199999999997,
#   238.2829,
#   490.5143999999999,
#   246.2829,
#   'une pollution sont orientés vers un exutoire ultime.'),
#  (9,
#   70.86609999999999,
#   233.83489999999998,
#   313.94678,
#   241.83489999999998,
#   'à avoir reçu une triple certiﬁ cation intégrée (certiﬁ cations Iso 9001, Iso 14001,'),
#  (9,
#   70.86609999999999,
#   222.83489999999998,
#   313.9551400000002,
#   230.83489999999998,
#   'Ohsas 18001). À cette triple certiﬁ cation obtenue en 2001 s’ajoute le référentiel'),
#  ...]

# %%
for (page_nb, x_min, y_min, x_max, y_max, text) in device.rows:
    if page_nb == 0:
